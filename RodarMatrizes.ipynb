# %%
import scipy
from io import StringIO
import numpy as np
from metpot import Pot
import os
import glob
import pandas as pd

# %%
caminho = 'matrizes/'
arquivos_na_pasta = glob.glob(os.path.join(caminho, '*'))

# %%
arquivos_na_pasta
# Out:
# ['matrizes/bfw398a.mtx',
#  'matrizes/bcsstm01.mtx',
#  'matrizes/bcsstk05.mtx',
#  'matrizes/1138_bus.mtx',
#  'matrizes/ck104.mtx',
#  'matrizes/dw2048.mtx',
#  'matrizes/bcsstk01.mtx',
#  'matrizes/ck400.mtx',
#  'matrizes/dw8192.mtx',
#  'matrizes/sherman4.mtx',
#  'matrizes/gr_30_30.mtx',
#  'matrizes/e05r0100.mtx',
#  'matrizes/fidap005.mtx']

# %%
coluna_nomes = []
coluna_ordem = []
coluna_campo = []
coluna_simetria = []
coluna_ite = []
coluna_autovalor = []
coluna_erro = []

# %%
for arquivo in arquivos_na_pasta:
    ordem, _, _, _, campo, simetria = scipy.io.mminfo(arquivo)
    matriz = scipy.io.mmread(arquivo)
    matriz.A
    A = np.array(matriz.A)
    n = A.shape[1]
    yo = np.ones(n)
    
    coluna_nomes.append(arquivo)
    coluna_ordem.append(ordem)
    coluna_campo.append(campo)
    coluna_simetria.append(simetria)
    
    try:
        i, e, autovalor= Pot(A, yo)
        coluna_ite.append(i)
        coluna_autovalor.append(autovalor)
        coluna_erro.append(e)
        
    except:
        coluna_ite.append('erro no calculo')
        coluna_autovalor.append('erro no calculo')
        coluna_erro.append('erro no calculo')
# Out:
# /home/jpfernandes/Área de Trabalho/jp_acad_prof/Faculdade/UFERSA/IC/Autov/codigos/metpot.py:34: RuntimeWarning: divide by zero encountered in divide
#   autovl = zs[-1]/ys[-1]
# /home/jpfernandes/Área de Trabalho/jp_acad_prof/Faculdade/UFERSA/IC/Autov/codigos/metpot.py:34: RuntimeWarning: invalid value encountered in divide
#   autovl = zs[-1]/ys[-1]
# /home/jpfernandes/Área de Trabalho/jp_acad_prof/Faculdade/UFERSA/IC/Autov/codigos/metpot.py:41: RuntimeWarning: invalid value encountered in divide
#   err = np.abs(autovls[-1] - autovls[-2]) / np.max(np.abs( autovls[-1] ))

# %%
dados = {
    'Matriz': coluna_nomes,
    'Autovalor': coluna_autovalor,
    'Iterações': coluna_ite,
    'Erros': coluna_erro,
    'Ordem': coluna_ordem,
    'Campo': coluna_campo,
    'Simetria': coluna_simetria
}

# %%
dados
# Out:
# {'Matriz': ['matrizes/bfw398a.mtx',
#   'matrizes/bcsstm01.mtx',
#   'matrizes/bcsstk05.mtx',
#   'matrizes/1138_bus.mtx',
#   'matrizes/ck104.mtx',
#   'matrizes/dw2048.mtx',
#   'matrizes/bcsstk01.mtx',
#   'matrizes/ck400.mtx',
#   'matrizes/dw8192.mtx',
#   'matrizes/sherman4.mtx',
#   'matrizes/gr_30_30.mtx',
#   'matrizes/e05r0100.mtx',
#   'matrizes/fidap005.mtx'],
#  'Autovalor': [10.890918078552891,
#   nan,
#   1361922.6408104694,
#   1474.8574148220223,
#   0.9569725780473788,
#   1.000000000000004,
#   1338325305.7142258,
#   1.0,
#   0.8473577524655383,
#   1.0,
#   10.718195859423563,
#   5.617973248956158,
#   3770611.8597459625],
#  'Iterações': [3, 10000, 2, 5, 2, 2, 2, 2, 2, 2, 15, 2, 2],
#  'Erros': [4.465025893178264e-08,
#   nan,
#   7.003315343114804e-14,
#   3.5231504480516034e-14,
#   2.0957794139813404e-05,
#   0.0,
#   2.7029905163095767e-06,
#   0.0,
#   0.0,
#   0.0,
#   2.5948322045262944e-05,
#   7.264830274118489e-05,
#   8.94833913191285e-06],
#  'Ordem': [398, 48, 153, 1138, 104, 2048, 48, 400, 8192, 1104, 900, 236, 27],
#  'Campo': ['real',
#   'real',
#   'real',
#   'real',
#   'real',
#   'real',
#   'real',
#   'real',
#   'real',
#   'real',
#   'integer',
#   'real',
#   'real'],
#  'Simetria': ['general',
#   'symmetric',
#   'symmetric',
#   'symmetric',
#   'general',
#   'general',
#   'symmetric',
#   'general',
#   'general',
#   'general',
#   'symmetric',
#   'general',
#   'general']}

# %%
df = pd.DataFrame( dados )

# %%
df
# Out:
#                    Matriz     Autovalor  Iterações         Erros  Ordem  \
# 0    matrizes/bfw398a.mtx  1.089092e+01          3  4.465026e-08    398
# 1   matrizes/bcsstm01.mtx           NaN      10000           NaN     48
# 2   matrizes/bcsstk05.mtx  1.361923e+06          2  7.003315e-14    153
# 3   matrizes/1138_bus.mtx  1.474857e+03          5  3.523150e-14   1138
# 4      matrizes/ck104.mtx  9.569726e-01          2  2.095779e-05    104
# 5     matrizes/dw2048.mtx  1.000000e+00          2  0.000000e+00   2048
# 6   matrizes/bcsstk01.mtx  1.338325e+09          2  2.702991e-06     48
# 7      matrizes/ck400.mtx  1.000000e+00          2  0.000000e+00    400
# 8     matrizes/dw8192.mtx  8.473578e-01          2  0.000000e+00   8192
# 9   matrizes/sherman4.mtx  1.000000e+00          2  0.000000e+00   1104
# 10  matrizes/gr_30_30.mtx  1.071820e+01         15  2.594832e-05    900
# 11  matrizes/e05r0100.mtx  5.617973e+00          2  7.264830e-05    236
# 12  matrizes/fidap005.mtx  3.770612e+06          2  8.948339e-06     27
#
#       Campo   Simetria
# 0      real    general
# 1      real  symmetric
# 2      real  symmetric
# 3      real  symmetric
# 4      real    general
# 5      real    general
# 6      real  symmetric
# 7      real    general
# 8      real    general
# 9      real    general
# 10  integer  symmetric
# 11     real    general
# 12     real    general
