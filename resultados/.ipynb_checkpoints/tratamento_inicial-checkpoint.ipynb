# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # MMQ junção dos dados

# %%
dfMMQ = pd.read_excel('comportamentoMMQ_preliminares.xlsx')

# %% [markdown]
# ## MP tratamento dos dados

# %%
dfMMQ = dfMMQ.drop(columns=dfMMQ.columns[dfMMQ.columns.str.contains('^Unnamed')])

# %%
dfMMQ['Matriz'] = dfMMQ['Matriz'].str.replace('.mtx', '')
dfMMQ['Matriz'] = dfMMQ['Matriz'].apply(lambda x: x.split('/')[-1])

# %%
dfMMQ
# Out:
#        Matriz Metodo        r2      ajuste   segundo grau  primeiro grau  \
# 0      arc130     MP  0.026316      Linear       0.000000    -993.264944
# 1      arc130     MP  0.145865   Logaritmo       0.000000  -82075.495528
# 2      arc130     MP  0.117004   Potencial       0.000000      -0.474311
# 3      arc130     MP  0.068650  Polinomial  169850.736099   -5916.408189
# 4    bcspwr04     MP  0.088717      Linear       0.000000      -0.628510
# ..        ...    ...       ...         ...            ...            ...
# 311  dwt_1007     MP  0.123404  Polinomial      47.754447      -2.474125
# 312   dwt_245     MP  0.057901      Linear       0.000000      -0.231583
# 313   dwt_245     MP  0.229475   Logaritmo       0.000000      -7.281627
# 314   dwt_245     MP  0.201570   Potencial       0.000000      -0.182162
# 315   dwt_245     MP  0.148578  Polinomial      25.630301      -1.378390
#
#       independente
# 0     75490.490571
# 1    327186.407066
# 2        15.447667
# 3        43.185467
# 4        23.056445
# ..             ...
# 311       0.033173
# 312      16.073580
# 313      31.740101
# 314      15.185030
# 315       0.023404
#
# [316 rows x 7 columns]

# %%
dfMMQ2 = dfMMQ[dfMMQ['r2'] != 'erro']

# %%
df2MMQ = dfMMQ2.query('r2 > 0.77')
df2MMQ = df2MMQ.query('Metodo == "MP" ')
df2MMQ
# Out:
#        Matriz Metodo        r2      ajuste  segundo grau  primeiro grau  \
# 17   1138_bus     MP  0.772483   Logaritmo  0.000000e+00   1.310238e+04
# 18   1138_bus     MP  0.758258   Potencial  0.000000e+00   1.345143e+00
# 19   1138_bus     MP  0.864371  Polinomial -9.464077e+03   5.214210e+03
# 21    685_bus     MP  0.777659   Logaritmo  0.000000e+00   1.926583e+02
# 22    685_bus     MP  0.777652   Potencial  0.000000e+00   7.394327e-03
# 23    685_bus     MP  0.934008  Polinomial  2.559547e+04   4.068288e+02
# 29    494_bus     MP  0.777956   Logaritmo  0.000000e+00   1.634563e+01
# 30    494_bus     MP  0.777947   Potencial  0.000000e+00   7.396882e-03
# 31    494_bus     MP  0.933974  Polinomial  2.170839e+03   3.449490e+01
# 37    662_bus     MP  0.778760   Logaritmo  0.000000e+00   1.050321e+01
# 38    662_bus     MP  0.778748   Potencial  0.000000e+00   7.418455e-03
# 39    662_bus     MP  0.934554  Polinomial  1.390797e+03   2.214944e+01
# 65   bcsstk02     MP  0.840110   Logaritmo  0.000000e+00   2.803435e+03
# 66   bcsstk02     MP  0.788960   Potencial  0.000000e+00   2.062315e-01
# 67   bcsstk02     MP  0.826742  Polinomial  1.009292e+04   9.537883e+02
# 69   bcsstk05     MP  0.894736   Logaritmo  0.000000e+00   1.450185e+06
# 70   bcsstk05     MP  0.841227   Potencial  0.000000e+00   3.838114e-01
# 71   bcsstk05     MP  0.907286  Polinomial  1.843515e+06   3.658056e+05
# 125  bcsstk25     MP  0.831652   Logaritmo  0.000000e+00   1.505794e+14
# 126  bcsstk25     MP  0.796810   Potencial  0.000000e+00   1.776666e-01
# 127  bcsstk25     MP  0.862942  Polinomial  6.167463e+14   6.151870e+13
# 193  bcsstm09     MP  0.866831   Logaritmo  0.000000e+00  -4.511190e-03
# 194  bcsstm09     MP  0.866831   Potencial  0.000000e+00  -2.848966e+00
# 195  bcsstm09     MP  1.000000  Polinomial  1.424612e-02  -1.165592e-02
#
#      independente
# 17  -6.240050e+03
# 18   7.531533e+02
# 19  -1.615754e+02
# 21   2.596758e+04
# 22   2.596740e+04
# 23  -6.558528e+01
# 29   2.202390e+03
# 30   2.202374e+03
# 31  -5.559967e+00
# 37   1.411056e+03
# 38   1.411046e+03
# 39  -3.569306e+00
# 65   1.014957e+04
# 66   1.011919e+04
# 67  -2.532116e+01
# 69   1.521193e+06
# 70   1.834514e+06
# 71  -7.044912e+03
# 125  6.503760e+14
# 126  6.557504e+14
# 127 -1.950688e+12
# 193  4.507465e-03
# 194  3.789314e-03
# 195  2.331183e-03

# %%
valores_unicos = df2MMQ['Matriz'].unique()

# %%
valores_unicos.size
# Out:
# 8

# %%
valores_unicos
# Out:
# array(['1138_bus', '685_bus', '494_bus', '662_bus', 'bcsstk02',
#        'bcsstk05', 'bcsstk25', 'bcsstm09'], dtype=object)

# %%
#salvar
df2MMQ.to_excel('tabelas_final/resultado_MMQ_final.xlsx')

# %% [markdown]
# Fim da junção dos resultados e inicio de analise exploratoria

# %% [markdown]
# # MP junção dos dados

# %%
dfMP = pd.read_excel('resultados_preliminares.xlsx')

# %% [markdown]
# ## MP tratamento dos dados

# %%
dfMP = dfMP.drop(columns=dfMP.columns[dfMP.columns.str.contains('^Unnamed')])

# %%
dfMP['Matriz'] = dfMP['Matriz'].str.replace('.mtx', '')
dfMP['Matriz'] = dfMP['Matriz'].apply(lambda x: x.split('/')[-1])

# %%
dfMP = dfMP.query('Método == "MP"')

# %%
dfMP
# Out:
#       Matriz Método     Autovalor  Iterações     Tempo  Ordem    Campo  \
# 0     arc130     MP      2.366980        113  0.009521    130     real
# 1   bcspwr04     MP     10.114256         30  0.001702    274  pattern
# 2   bcspwr02     MP      4.308259         40  0.001505     49  pattern
# 3   bcspwr03     MP      5.104674         35  0.001817    118  pattern
# 4   1138_bus     MP  30115.826300         22  0.017090   1138     real
# ..       ...    ...           ...        ...       ...    ...      ...
# 74  dwt_1005     MP     16.406360         14  0.009660   1005  pattern
# 75  sherman4     MP     66.487670        100  0.057505   1104     real
# 76  dwt_1242     MP      9.389296        105  0.074697   1242  pattern
# 77  dwt_1007     MP      8.912431         61  0.030167   1007  pattern
# 78   dwt_245     MP      8.523647         48  0.005911    245  pattern
#
#      Simetria
# 0     general
# 1   symmetric
# 2   symmetric
# 3   symmetric
# 4   symmetric
# ..        ...
# 74  symmetric
# 75    general
# 76  symmetric
# 77  symmetric
# 78  symmetric
#
# [79 rows x 8 columns]

# %% [markdown]
# ## Olhar Matrizes com alto r2

# %%
linhas_filtradas = dfMP[dfMP['Matriz'].isin(valores_unicos)]

# %%
linhas_filtradas
# Out:
#       Matriz Método     Autovalor  Iterações     Tempo  Ordem Campo   Simetria
# 4   1138_bus     MP  3.011583e+04         22  0.017090   1138  real  symmetric
# 5    685_bus     MP  2.618649e+04          4  0.001264    685  real  symmetric
# 7    494_bus     MP  2.220968e+03          4  0.000593    494  real  symmetric
# 9    662_bus     MP  1.422995e+03          4  0.001286    662  real  symmetric
# 16  bcsstk02     MP  1.822529e+04         28  0.001504     66  real  symmetric
# 17  bcsstk05     MP  6.197044e+06         38  0.002492    153  real  symmetric
# 31  bcsstk25     MP  1.060008e+15         23  2.916399  15439  real  symmetric
# 48  bcsstm09     MP  2.590204e-04          3  0.002291   1083  real  symmetric

# %%
#salvar
dfMP.to_excel('tabelas_final/resultado_MP_final.xlsx')
linhas_filtradas.to_excel('tabelas_final/resultado_MP_MMQ.xlsx')
