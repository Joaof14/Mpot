# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('resultados.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 792 entries, 0 to 791
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Matriz      792 non-null    object
#  1   Aceleração  792 non-null    object
#  2   Autovalor   792 non-null    float64
#  3   Iterações   792 non-null    int64
#  4   Tempo       792 non-null    float64
#  5   Erros       787 non-null    float64
#  6   Ordem       792 non-null    int64
#  7   Campo       792 non-null    object
#  8   Simetria    792 non-null    object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 61.9+ KB

# %%
df['Matriz'] = df['Matriz'].str.strip('.mtx')

# %%
df.isna().sum()
# Out:
# Matriz        0
# Aceleração    0
# Autovalor     0
# Iterações     0
# Tempo         0
# Erros         5
# Ordem         0
# Campo         0
# Simetria      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Matriz', 'Aceleração', 'Autovalor', 'Iterações', 'Tempo', 'Erros',
#        'Ordem', 'Campo', 'Simetria'],
#       dtype='object')

# %%
df[df['Erros'] == float('inf')]
# Out:
#          Matriz       Aceleração  Autovalor  Iterações     Tempo  Erros  \
# Indice
# 421      bp_800    MMQ_Potencial  18.843512      10000  1.069381    inf
# 436      bp_400  MMQ_Exponencial  15.068339      10000  1.023928    inf
# 437      bp_400    MMQ_Potencial  15.068339      10000  1.028801    inf
# 501     bp_1200    MMQ_Potencial  14.283015      10000  1.046807    inf
#
#         Ordem Campo Simetria
# Indice
# 421       822  real  general
# 436       822  real  general
# 437       822  real  general
# 501       822  real  general

# %%
df.replace(float('inf'), np.nan, inplace=True)

# %%
df.isna().sum()
# Out:
# Matriz        0
# Aceleração    0
# Autovalor     0
# Iterações     0
# Tempo         0
# Erros         9
# Ordem         0
# Campo         0
# Simetria      0
# dtype: int64

# %%
df_na = df[df['Erros'].isna()]
df_na
# Out:
#          Matriz       Aceleração  Autovalor  Iterações     Tempo  Erros  \
# Indice
# 421      bp_800    MMQ_Potencial  18.843512      10000  1.069381    NaN
# 436      bp_400  MMQ_Exponencial  15.068339      10000  1.023928    NaN
# 437      bp_400    MMQ_Potencial  15.068339      10000  1.028801    NaN
# 438      bp_400   MMQ_Geometrico  15.068339      10000  1.011769    NaN
# 492     bp_1000  MMQ_Exponencial  13.279637      10000  1.037349    NaN
# 493     bp_1000    MMQ_Potencial  13.279637      10000  1.115787    NaN
# 494     bp_1000   MMQ_Geometrico  13.279637      10000  1.194812    NaN
# 501     bp_1200    MMQ_Potencial  14.283015      10000  1.046807    NaN
# 517     bp_1600    MMQ_Potencial  23.323862      10000  1.059236    NaN
#
#         Ordem Campo Simetria
# Indice
# 421       822  real  general
# 436       822  real  general
# 437       822  real  general
# 438       822  real  general
# 492       822  real  general
# 493       822  real  general
# 494       822  real  general
# 501       822  real  general
# 517       822  real  general

# %%
matrizes_na = list(df_na['Matriz'])

# %%
matrizes_na = list(set(matrizes_na))

# %%
matrizes_na
# Out:
# ['bp_800', 'bp_1000', 'bp_1200', 'bp_1600', 'bp_400']

# %%
df = df[~df['Matriz'].isin(matrizes_na)]

# %%
df
# Out:
#           Matriz       Aceleração     Autovalor  Iterações      Tempo  \
# Indice
# 0       bcspwr02          Nenhuma  4.308259e+00         40   0.001107
# 1       bcspwr02           Aitken  4.306108e+00         24   0.000627
# 2       bcspwr02       MMQ_Linear  4.308051e+00         36   0.005209
# 3       bcspwr02    MMQ_Logaritmo  4.307899e+00         34   0.005140
# 4       bcspwr02  MMQ_Exponencial  4.308565e+00      10000   0.739407
# ...          ...              ...           ...        ...        ...
# 787     bcsstm23    MMQ_Logaritmo  8.270344e+06         19   0.051783
# 788     bcsstm23  MMQ_Exponencial  8.270348e+06      10000  26.157234
# 789     bcsstm23    MMQ_Potencial  8.270348e+06      10000  26.463039
# 790     bcsstm23   MMQ_Geometrico  8.270346e+06         20   0.058933
# 791     bcsstm23   MMQ_Polinomial  8.270344e+06         19   0.049184
#
#                 Erros  Ordem    Campo   Simetria
# Indice
# 0            0.000010     49  pattern  symmetric
# 1            0.000008     49  pattern  symmetric
# 2            0.000009     49  pattern  symmetric
# 3            0.000009     49  pattern  symmetric
# 4            1.949850     49  pattern  symmetric
# ...               ...    ...      ...        ...
# 787          0.000010   3134     real  symmetric
# 788     519226.091093   3134     real  symmetric
# 789     519221.888314   3134     real  symmetric
# 790          0.000005   3134     real  symmetric
# 791          0.000008   3134     real  symmetric
#
# [752 rows x 9 columns]

# %%
df.reset_index()
# Out:
#      Indice    Matriz       Aceleração     Autovalor  Iterações      Tempo  \
# 0         0  bcspwr02          Nenhuma  4.308259e+00         40   0.001107
# 1         1  bcspwr02           Aitken  4.306108e+00         24   0.000627
# 2         2  bcspwr02       MMQ_Linear  4.308051e+00         36   0.005209
# 3         3  bcspwr02    MMQ_Logaritmo  4.307899e+00         34   0.005140
# 4         4  bcspwr02  MMQ_Exponencial  4.308565e+00      10000   0.739407
# ..      ...       ...              ...           ...        ...        ...
# 747     787  bcsstm23    MMQ_Logaritmo  8.270344e+06         19   0.051783
# 748     788  bcsstm23  MMQ_Exponencial  8.270348e+06      10000  26.157234
# 749     789  bcsstm23    MMQ_Potencial  8.270348e+06      10000  26.463039
# 750     790  bcsstm23   MMQ_Geometrico  8.270346e+06         20   0.058933
# 751     791  bcsstm23   MMQ_Polinomial  8.270344e+06         19   0.049184
#
#              Erros  Ordem    Campo   Simetria
# 0         0.000010     49  pattern  symmetric
# 1         0.000008     49  pattern  symmetric
# 2         0.000009     49  pattern  symmetric
# 3         0.000009     49  pattern  symmetric
# 4         1.949850     49  pattern  symmetric
# ..             ...    ...      ...        ...
# 747       0.000010   3134     real  symmetric
# 748  519226.091093   3134     real  symmetric
# 749  519221.888314   3134     real  symmetric
# 750       0.000005   3134     real  symmetric
# 751       0.000008   3134     real  symmetric
#
# [752 rows x 10 columns]

# %%
df.drop('Indice',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 df.drop('Indice',axis=1)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['Indice'] not found in axis"
