# %%
import pandas as pd
import numpy as np

# %%
dfMMQ = pd.read_excel('resultado_MMQ_final.xlsx')

# %%
df2 = dfMMQ.query('r2 > 0.8 & r2 < 0.9 & Metodo.str.endswith("P")')

# %%
dfMMQ.query('Matriz.str.startswith("c130") & Metodo.str.endswith("P")')
# Out:
#     Unnamed: 0 Matriz Metodo        r2       ajuste   segundo grau  \
# 60          60   c130     MP  0.026316       Linear       0.000000
# 61          61   c130     MP  0.145865    Logaritmo       0.000000
# 62          62   c130     MP  0.017553  Exponencial       0.000000
# 63          63   c130     MP  0.017553   Geometrico       0.000000
# 64          64   c130     MP  0.117004    Potencial       0.000000
# 65          65   c130     MP  0.068650   Polinomial  169850.736099
#
#     primeiro grau   independente
# 60    -993.264944   75490.490571
# 61  -82075.495528  327186.407066
# 62      -0.005234       3.504648
# 63       0.994779       3.504648
# 64      -0.474311      15.447667
# 65   -5916.408189      43.185467

# %%
dfMMQ.query('Matriz.str.startswith("bcsstk21") & Metodo.str.endswith("P")')
# Out:
#      Unnamed: 0    Matriz Metodo        r2       ajuste  segundo grau  \
# 432         432  bcsstk21     MP  0.001128       Linear  0.000000e+00
# 433         433  bcsstk21     MP  0.032894    Logaritmo  0.000000e+00
# 434         434  bcsstk21     MP  0.029635  Exponencial  0.000000e+00
# 435         435  bcsstk21     MP  0.029635   Geometrico  0.000000e+00
# 436         436  bcsstk21     MP  0.026261    Potencial  0.000000e+00
# 437         437  bcsstk21     MP  0.005496   Polinomial  1.429319e+08
#
#      primeiro grau  independente
# 432  -2.521903e+04  1.321018e+08
# 433  -1.362658e+07  1.936207e+08
# 434   2.807779e-04  1.187290e+08
# 435   1.000281e+00  1.187290e+08
# 436   2.644283e-02  1.095535e+08
# 437  -2.180399e+05  5.738716e+02

# %%
dfMMQ.query('Matriz.str.startswith("bcspwr05") & Metodo.str.endswith("P")')
# Out:
#      Unnamed: 0    Matriz Metodo        r2       ajuste  segundo grau  \
# 120         120  bcspwr05     MP  0.033990       Linear      0.000000
# 121         121  bcspwr05     MP  0.169847    Logaritmo      0.000000
# 122         122  bcspwr05     MP  0.023187  Exponencial      0.000000
# 123         123  bcspwr05     MP  0.023187   Geometrico      0.000000
# 124         124  bcspwr05     MP  0.137680    Potencial      0.000000
# 125         125  bcspwr05     MP  0.089562   Polinomial     13.676728
#
#      primeiro grau  independente
# 120      -0.068620      8.916383
# 121      -3.932378     19.602543
# 122      -0.002014      5.766212
# 123       0.997988      5.766212
# 124      -0.125814      8.177224
# 125      -0.412742      0.004197

# %%
dfMMQ.query('Matriz.str.startswith("dwt_1242") & Metodo.str.endswith("P")')
# Out:
#      Unnamed: 0    Matriz Metodo        r2       ajuste  segundo grau  \
# 924         924  dwt_1242     MP  0.027574       Linear      0.000000
# 925         925  dwt_1242     MP  0.150385    Logaritmo      0.000000
# 926         926  dwt_1242     MP  0.022007  Exponencial      0.000000
# 927         927  dwt_1242     MP  0.022007   Geometrico      0.000000
# 928         928  dwt_1242     MP  0.135066    Potencial      0.000000
# 929         929  dwt_1242     MP  0.072445   Polinomial     34.375028
#
#      primeiro grau  independente
# 924      -0.156645     20.439404
# 925     -11.976060     56.267595
# 926      -0.001656     10.533003
# 927       0.998345     10.533003
# 928      -0.134307     15.825963
# 929      -0.938082      0.007372

# %%
df3 = dfMMQ.query('Matriz.str.startswith("bcsstk27") & Metodo.str.endswith("P") & r2 >0.3')

# %%
df2 = pd.concat([df2,df3], ignore_index = True)
df2 = df2.drop(columns=df2.columns[df2.columns.str.contains('^Unnamed')])

# %%
df_sem_colunas = df2.drop(columns=['Metodo'])

# %%
df_sem_colunas
# Out:
#       Matriz        r2      ajuste  segundo grau  primeiro grau  independente
# 0     38_bus  0.864371  Polinomial -9.464077e+03   5.214210e+03 -1.615754e+02
# 1   bcsstk05  0.894736   Logaritmo  0.000000e+00   1.450185e+06  1.521193e+06
# 2   bcsstk05  0.841227   Potencial  0.000000e+00   3.838114e-01  1.834514e+06
# 3   bcsstk02  0.840110   Logaritmo  0.000000e+00   2.803435e+03  1.014957e+04
# 4   bcsstk02  0.826742  Polinomial  1.009292e+04   9.537883e+02 -2.532116e+01
# 5   bcsstk25  0.831652   Logaritmo  0.000000e+00   1.505794e+14  6.503760e+14
# 6   bcsstk25  0.862942  Polinomial  6.167463e+14   6.151870e+13 -1.950688e+12
# 7   bcsstm09  0.866831   Logaritmo  0.000000e+00  -4.511190e-03  4.507465e-03
# 8   bcsstm09  0.866831   Potencial  0.000000e+00  -2.848966e+00  3.789314e-03
# 9   bcsstk27  0.335973   Logaritmo  0.000000e+00   1.871216e+05  2.725251e+06
# 10  bcsstk27  0.328773  Polinomial  2.892911e+06   2.330705e+04 -2.116498e+02

# %%
df4 = df_sem_colunas

# %%
df4 = df4.drop(df4[df4['Matriz'] == '38_bus'].index)

# %%
df4 = df4.drop(df4[df4['Matriz'] == 'bcsstm09'].index)

# %%
df4.reset_index
# Out:
# <bound method DataFrame.reset_index of       Matriz        r2      ajuste  segundo grau  primeiro grau  independente
# 1   bcsstk05  0.894736   Logaritmo  0.000000e+00   1.450185e+06  1.521193e+06
# 2   bcsstk05  0.841227   Potencial  0.000000e+00   3.838114e-01  1.834514e+06
# 3   bcsstk02  0.840110   Logaritmo  0.000000e+00   2.803435e+03  1.014957e+04
# 4   bcsstk02  0.826742  Polinomial  1.009292e+04   9.537883e+02 -2.532116e+01
# 5   bcsstk25  0.831652   Logaritmo  0.000000e+00   1.505794e+14  6.503760e+14
# 6   bcsstk25  0.862942  Polinomial  6.167463e+14   6.151870e+13 -1.950688e+12
# 9   bcsstk27  0.335973   Logaritmo  0.000000e+00   1.871216e+05  2.725251e+06
# 10  bcsstk27  0.328773  Polinomial  2.892911e+06   2.330705e+04 -2.116498e+02>

# %%
df4
# Out:
#       Matriz        r2      ajuste  segundo grau  primeiro grau  independente
# 1   bcsstk05  0.894736   Logaritmo  0.000000e+00   1.450185e+06  1.521193e+06
# 2   bcsstk05  0.841227   Potencial  0.000000e+00   3.838114e-01  1.834514e+06
# 3   bcsstk02  0.840110   Logaritmo  0.000000e+00   2.803435e+03  1.014957e+04
# 4   bcsstk02  0.826742  Polinomial  1.009292e+04   9.537883e+02 -2.532116e+01
# 5   bcsstk25  0.831652   Logaritmo  0.000000e+00   1.505794e+14  6.503760e+14
# 6   bcsstk25  0.862942  Polinomial  6.167463e+14   6.151870e+13 -1.950688e+12
# 9   bcsstk27  0.335973   Logaritmo  0.000000e+00   1.871216e+05  2.725251e+06
# 10  bcsstk27  0.328773  Polinomial  2.892911e+06   2.330705e+04 -2.116498e+02

# %%
def preencher_coluna(row):
    if row['ajustes'] == 'Logaritmo':
        return 'valor_para_ajuste1'
    elif row['ajustes'] == 'ajuste2':
        return 'valor_para_ajuste2'
    else:
        return 'valor_padrao'

# %%
df4.to_excel('filtragem.xlsx')
