# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # MMQ junção dos dados

# %%
dfMMQ = pd.read_excel('comportamentoMMQ_preliminares.xlsx')

# %% [markdown]
# ## MP tratamento dos dados

# %%
dfMMQ = dfMMQ.drop(columns=dfMMQ.columns[dfMMQ.columns.str.contains('^Unnamed')])

# %%
dfMMQ['Matriz'] = dfMMQ['Matriz'].str.replace('.mtx', '')
dfMMQ['Matriz'] = dfMMQ['Matriz'].apply(lambda x: x.split('/')[-1])

# %%
dfMMQ
# Out:
#       Matriz     Metodo        r2       ajuste segundo grau primeiro grau  \
# 0     arc130         MP  0.301448       Linear            0      0.001901
# 1     arc130         MP  0.577474    Logaritmo            0      0.111435
# 2     arc130         MP  0.271805  Exponencial            0       0.00088
# 3     arc130         MP  0.271805   Geometrico            0      1.000881
# 4     arc130         MP   0.53691    Potencial            0      0.052399
# ..       ...        ...       ...          ...          ...           ...
# 943  dwt_245  MP_Aitken  0.601291    Logaritmo            0       0.04898
# 944  dwt_245  MP_Aitken  0.385293  Exponencial            0      0.000279
# 945  dwt_245  MP_Aitken  0.385293   Geometrico            0      1.000279
# 946  dwt_245  MP_Aitken  0.599739    Potencial            0      0.005784
# 947  dwt_245  MP_Aitken  0.712655   Polinomial     8.374526      0.013239
#
#     independente
# 0       2.210914
# 1       1.892342
# 2       2.202644
# 3       2.202644
# 4       1.894693
# ..           ...
# 943     8.368256
# 944     8.461377
# 945     8.461377
# 946     8.368678
# 947    -0.000272
#
# [948 rows x 7 columns]

# %%
dfMMQ2 = dfMMQ[dfMMQ['r2'] != 'erro']

# %%
df2MMQ = dfMMQ2.query('r2 > 0.95')
df2MMQ = df2MMQ.query('Metodo == "MP" ')
df2MMQ
# Out:
#        Matriz Metodo        r2       ajuste         segundo grau  \
# 185  bcsstk03     MP  0.962548   Polinomial   78447523902.777939
# 401  bcsstk26     MP  0.984326   Polinomial  126130840010.724396
# 480  bcsstm20     MP  0.987907       Linear                    0
# 482  bcsstm20     MP  0.987839  Exponencial                    0
# 483  bcsstm20     MP  0.987839   Geometrico                    0
# 485  bcsstm20     MP  0.999939   Polinomial      47629988.231112
# 493  bcsstm19     MP  0.980317    Logaritmo                    0
# 496  bcsstm19     MP  0.980459    Potencial                    0
# 497  bcsstm19     MP  0.989971   Polinomial      38821555.053761
# 601   can_187     MP  0.998745    Logaritmo                    0
# 604   can_187     MP  0.998752    Potencial                    0
# 605   can_187     MP  0.993174   Polinomial             8.380646
# 665   can_445     MP  0.951706   Polinomial             8.878315
# 725     ck400     MP  0.991008   Polinomial             5.510435
# 749     ck104     MP  0.978192   Polinomial             5.515113
# 769    dw2048     MP  0.974363    Logaritmo                    0
# 772    dw2048     MP  0.974195    Potencial                    0
# 773    dw2048     MP  0.992434   Polinomial             0.947869
# 785   dwt_162     MP  0.961557   Polinomial             7.961904
# 793   dwt_198     MP  0.953062    Logaritmo                    0
# 796   dwt_198     MP  0.952446    Potencial                    0
# 797   dwt_198     MP  0.959423   Polinomial             8.114769
# 845  fidap005     MP  0.968056   Polinomial       3669012.730239
# 869  e05r0100     MP  0.953651   Polinomial              12.7323
# 913  dwt_1242     MP  0.955864    Logaritmo                    0
# 916  dwt_1242     MP  0.954622    Potencial                    0
#
#          primeiro grau      independente
# 185  12011186540.41745 -290904766.468894
# 401  1788698498.537045   -24281775.02732
# 480         855.052486   47640335.691204
# 482           0.000018   47640361.670794
# 483           1.000018   47640361.670794
# 485        1243.725738         -2.573995
# 493      254638.280586   38331079.327807
# 496           0.006488   38341091.469281
# 497       12838.776729        -57.942289
# 601           0.006567          8.371145
# 604           0.000783          8.371167
# 605            0.00059         -0.000005
# 665           0.004417         -0.000067
# 725          -0.001775          0.000097
# 749          -0.002927          0.000166
# 769            0.01092          0.930396
# 772           0.011294          0.931034
# 773            0.00078         -0.000005
# 785           0.007726         -0.000086
# 793           0.043737          8.054986
# 796            0.00534          8.056003
# 797            0.00403         -0.000033
# 845       43233.304362       -646.954401
# 869          -0.001863          0.000002
# 913           0.080851          9.035279
# 916           0.008697          9.038627

# %%
valores_unicos = df2MMQ['Matriz'].unique()

# %%
valores_unicos.size
# Out:
# 14

# %%
valores_unicos
# Out:
# array(['bcsstk03', 'bcsstk26', 'bcsstm20', 'bcsstm19', 'can_187',
#        'can_445', 'ck400', 'ck104', 'dw2048', 'dwt_162', 'dwt_198',
#        'fidap005', 'e05r0100', 'dwt_1242'], dtype=object)

# %%
#salvar
df2MMQ.to_excel('tabelas_final/resultado_MMQ_final.xlsx')

# %% [markdown]
# Fim da junção dos resultados e inicio de analise exploratoria

# %% [markdown]
# # MP junção dos dados

# %%
dfMP = pd.read_excel('resultados_preliminares.xlsx')

# %% [markdown]
# ## MP tratamento dos dados

# %%
dfMP = dfMP.drop(columns=dfMP.columns[dfMP.columns.str.contains('^Unnamed')])

# %%
dfMP['Matriz'] = dfMP['Matriz'].str.replace('.mtx', '')
dfMP['Matriz'] = dfMP['Matriz'].apply(lambda x: x.split('/')[-1])

# %%
dfMP = dfMP.query('Método == "MP"')

# %%
dfMP
# Out:
#        Matriz Método     Autovalor  Iterações     Tempo  Ordem    Campo  \
# 0      arc130     MP      2.366980        113  0.003822    130     real
# 2    bcspwr04     MP     10.114256         30  0.001075    274  pattern
# 4    bcspwr02     MP      4.308259         40  0.000854     49  pattern
# 6    bcspwr03     MP      5.104674         35  0.001263    118  pattern
# 8    1138_bus     MP  30115.826300         22  0.012069   1138     real
# ..        ...    ...           ...        ...       ...    ...      ...
# 148  dwt_1005     MP     16.406360         14  0.006503   1005  pattern
# 150  sherman4     MP     66.487670        100  0.040897   1104     real
# 152  dwt_1242     MP      9.389296        105  0.060825   1242  pattern
# 154  dwt_1007     MP      8.912431         61  0.023270   1007  pattern
# 156   dwt_245     MP      8.523647         48  0.002196    245  pattern
#
#       Simetria
# 0      general
# 2    symmetric
# 4    symmetric
# 6    symmetric
# 8    symmetric
# ..         ...
# 148  symmetric
# 150    general
# 152  symmetric
# 154  symmetric
# 156  symmetric
#
# [79 rows x 8 columns]

# %% [markdown]
# ## Olhar Matrizes com alto r2

# %%
linhas_filtradas = dfMP[dfMP['Matriz'].isin(valores_unicos)]

# %%
linhas_filtradas
# Out:
#        Matriz Método     Autovalor  Iterações     Tempo  Ordem    Campo  \
# 30   bcsstk03     MP  1.997327e+11         25  0.002558    112     real
# 66   bcsstk26     MP  1.582688e+11         46  0.125740   1922     real
# 80   bcsstm20     MP  4.775632e+07        146  0.015244    485     real
# 82   bcsstm19     MP  3.953672e+07        130  0.025841    817     real
# 100   can_187     MP  8.397620e+00         58  0.002664    187  pattern
# 110   can_445     MP  8.950130e+00         43  0.002928    445  pattern
# 120     ck400     MP  5.502386e+00         10  0.001065    400     real
# 124     ck104     MP  5.502386e+00         10  0.000530    104     real
# 128    dw2048     MP  9.782281e-01        100  0.243376   2048     real
# 130   dwt_162     MP  8.131174e+00         60  0.002860    162  pattern
# 132   dwt_198     MP  8.235968e+00         82  0.004384    198  pattern
# 140  fidap005     MP  4.359441e+06         45  0.002341     27     real
# 144  e05r0100     MP  1.241717e+01        233  0.014924    236     real
# 152  dwt_1242     MP  9.389296e+00        105  0.060825   1242  pattern
#
#       Simetria
# 30   symmetric
# 66   symmetric
# 80   symmetric
# 82   symmetric
# 100  symmetric
# 110  symmetric
# 120    general
# 124    general
# 128    general
# 130  symmetric
# 132  symmetric
# 140    general
# 144    general
# 152  symmetric

# %%
#salvar
dfMP.to_excel('tabelas_final/resultado_MP_final.xlsx')
linhas_filtradas.to_excel('tabelas_final/resultado_MP_MMQ.xlsx')
